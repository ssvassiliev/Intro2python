# %% [markdown]
# # Introductory Programming with Python (Part 1)
#
# ### 1. Your Learning Journey: Solving Real Problems
#
# Nothing teaches you faster than wrestling with real-world practical challenges. That's why this course centers on a fundamental skill you'll apply throughout your career: deriving insights from data. We'll work with real-world examples such as analyzing trends or uncovering insights from datasets - precisely the kind of tasks professionals encounter daily.
#
# You'll pick up coding by actually doing it — starting with real, useful project and building meaningful insights from your very first session.
#
# ### What You'll Gain
# You'll gain core skills including data analysis and transformation, insightful visualization techniques, and writing efficient, maintainable code. Along the way, you'll also learn best practices like error handling, debugging, and designing robust programs.
#
# By the end of our workshop, you'll be able to:
# - Extract key insights: Calculate key metrics (e.g., averages) and identify patterns.
# - Make data visual: Create clear charts that tell compelling stories
# - Solve puzzles: Fix errors and improve your code
# - Build solutions: Automate tasks that used to take hours
# - Think like a programmer: Break big problems into manageable steps
#
# ### Most importantly, you'll develop skills that transfer to many diferent fields.
#
# For example:
#
# - In Science and Research Python can be used: to Decode DNA patterns, physicists simulate black holes, and chemists model how molecules interact. Instead of manual calculations, Python handles massive datasets in seconds.
#
# - Engineers can use Python to simulate real-world stress on bridges or car parts before building them. Python also controls robots—like factory arms assembling products — or monitors sensors.
#
# -  Businesses rely on Python to spot trends, make decisions, and automate financial reports. Python can answer questions like, "Which product will sell best next season?" by analysing past data.
#
# - Python Dominates AI with its ready to use tools like TensorFlow, PyTorch, and scikit-learn. These tools are commonly used for Smart Recommendations, Facial Recognition, Chatbots, Generating Art & Text .. etc.
#
# And countless other fields benefit from using Python.

# %% [markdown]
# Now that we've covered the workshop goals and what you'll be able to accomplish by the end, it's time to get started with Python coding. Before we begin let's talk about installation of Python packages.
#
# ### 2. Python installation and usage.
#
# There are different ways to install python on a laptop.
#
# The easiest way to install Python on your laptop is through the official Python installer. This will install only Python interpreter. To start doing something useful you will need various libraries. If you are working on one project you can install all libraries it needs in your home directory or system-wide if you have privilege to do that.
#
# However, imagine that you need to work with two projects and these projects need diferent versions of a library.  So if you install correct version for the second project your first project will stop woking. Installing one project breaks the other!
#
# #### Python virtual environments
#
# To get several python projects working we need to isolate them. Without isolation, both projects share the same Python installation and this results in chaos.
#
# This problem is solved by creating an isolated environment for each project. These environments are known as "Python virtual environments". What is the python virtual environment?
#
# It’s a self-contained folder that holds:
#
# - A specific Python version
# - Only the libraries your project needs
#
# It is like a sandbox or a bubble — everything inside stays separate from the outside world.
#
# ####  Tools for creating virtual environments: virtualenv and conda.
# There are two main tools for creating virtual environments: virtualenv and conda. These tool not only create virtual environments. They also are used to install and manage Python packages. They have the same functionality, but they also have some important technical differences.
# The most important difference is that virtualenv installs Python packages only while conda installs non-Python binaries, including system libraries such as CUDA, MKL, etc.. As a result virtualenv needs a lot less disk space than conda.  On average virtualenv uses ~20-50 MB per environment while conda environments including shared binaries can easily use ~500 MB - 2 GB.
#
# While conda works reasonably well on personal computers it is a huge headake on HPC clusters for many reasons:
# - there's the filesystem abuse. Conda environments are directory trees with thousands of tiny files - the worst possible case for parallel filesystems designed for large files transfer.
# - Most HPC centers including our systems forbid internet access from compute nodes, but conda constantly phones home for updates.
# - HPC centers tune their software modules for optimal performance. Conda overwrites them with generic binaries. The resulting performance hits can be catastrophic for scientific codes.
#
# #### Setup
# Now we are finally ready to start. What you’ll need? You’ll need either:
#
# - Python installed locally (we recommend to install Anaconda because it provides everything you'll need today including Jupyter server and Python libaraies), or
# - You can access our training cluster via JupyterHub – just a Browser and Internet required.
#
# Any setup questions before we proceed?
#
# To run Python, we are going to use Jupyter Notebooks via JupyterLab. Let me start with  a brief introduction to Jupyter Notebooks. The Jupyter notebook is an excellent tool for executing Python code interactively. In a notebook, you can store executable code, textual documentation, and visualizations in one place. This makes them ideal for sharing your work. Using a notebook, collaborators can replicate findings without asking 'how did you do this?'
#
# You can think of a notebook as a dynamic research journal where you can explore data, test hypotheses, and record insights.
#
# Let me do a quick demo - to give you a glimse of what you'll experience.

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(-10,10,1000)
plt.plot(x,np.sinc(x))

# %% [markdown]
# ## 3. A brief introduction to Python
# ### Why Python is so popular?
#
# Now that we're all set up with Python (whether locally or via our Jupyter Hub), let's address the elephant in the room: Why Python? Why did this language has become a language of choice for science and technology folks and now dominates fields from AI to astronomy?
#
# Short answer - it handles the boring and time consuming coding bits so you can focus on what actually matters: solving big problems. Python is all about being flexible, practical, and powerful.
#
# It handles the tedious and boring coding bits (memory management, complex syntax, and low-level operations) so you can focus on solving meaningful problems. But its real power? Python is a universal problem-solving toolkit.
#
# - It seamlessly connects domains: you can analyze lab data with pandas, train an AI model with pytorch and deploy it as a web app with Flask – all in one language.
#
# - Python became a total game-changer for scientific computing and data analysis. NumPy/Pandas libraries  literally revolutionized data analysis by combining Python's ease with C-level performance.
#
# - Python's open-source code is massive – whatever problem you're tackling, there's likely a pre-built solution waiting (no reinventing the wheel required!).
#
#
# ### How Python stands out from other programming languages?
#
# - Using Python, you can write code that reads like plain English because of its human-friendly syntax.
#
# Python language is simple, and human-like which means it is intuitive (What it intuitive of course is subjective and depend on the background). However, I believe most users will find Python intuitive (at least the majority of users). Its syntax is designed to be easy to read - it is clean with strict indentation .. and it doesn't make you memorize complicated rules (when possible).
#
# Python code often reads like plain English instructions unlike other programming languages notorious for their challenging syntax (such as Perl or C++).
#
# Also Regular Expressions are worth mentioning: It is not a general purpose language, but rather a Domain Specific Landuage - a specialized language designed for pattern matching in text. Regular expressions are exceptionally powerful for text manipulations - they allow users to define rules for finding, extracting, or replacing text based on specific sequences of characters and they solve real problems very efficiently. They are supported by almost all programming languages and tools. But their power comes with significant trade-offs.  RegExes have a notoriously dense syntax.
#
# Here's an example of a regular expression designed to extract email addresses:

# %%
import re
text="admin@local, @missingusername.com,john.smith@company.org"
emails=re.findall(r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Z|a-z]{2,7}\b', text)
emails
# Out:
# ['john.smith@company.org']

# %% [markdown]
# Compare it to Python code to calculate average speed -  you'll write:

# %%
speed = [50, 60, 80, 85, 92]  
average = sum(speed) / len(speed)
average
# Out:
# 73.4

# %% [markdown]
# ### Object-Oriented by Design: Python’s Blueprint for Clean Code
# Python is object-oriented - uses classes and objects to organize code and data. What exactly does it mean of coders? Object Oriented Programming organizes code into "objects" which have properties (attributes) and behaviors (methods). Objects are instances of classes - blueprints that define an object's properties and actions.
#
# Everything in Python is an object (even integers and strings).

# %% [markdown]
# - Every integer is an instance of the int class

# %%
num = 500  # + 23j
print(type(num))
# Out:
# <class 'int'>

# %% [markdown]
# #### What does this mean?  - Let's have a quick look at the integer object num whcih we have just created.
# - Integers have sevral data attributes two of them are real and imag.

# %%
print("Real:", num.real, "Imaginary:",  num.imag)   
# Integers have two data attributes (real, imag)
# Out:
# Real: 500 Imaginary: 0

# %% [markdown]
# - Integers have methods like conjugate(), bit_length(), etc.

# %%
num.bit_length()
# Out:
# 9

# %% [markdown]
# ### Why should you care about OOP?
#
# There are many benefits, I'll mention only some of them:
# - With OOP code is organized into self-contained objects. It is easier to read, maintain, and debug.
# - Data and methods are bundled together, and access can be controlled. This hides internal complexity and helps to prevent accidental misuse.
# - You can create new classes by inheriting from existing ones. Using inheritance you write less code and extend functionality easily.
#
# To summarize: using objects helps to hide technical details, expose only what’s needed, extend functionality easily.
#
# - Python offers dynamic memory management. What does it mean? Python automatically allocates memory when you create objects (for examle variables, lists, classes). Python's garbage collector tracks unused objects and reclaims memory. You don't have to worry about allocating and freeing memory. These features are especially beneficial for beginners - they let you focus on solving problems – not managing memory.
#
# - Python works anywhere — your laptop, workstation or a supercomputer
#
#
# ### Python’s Trade-Offs: Where It Shines (and Where It Doesn’t)
#
# Every tool has limits — knowing them helps you choose wisely.  Python is brilliant for 90% of tasks, but you'd use a specialized tool for some demanding tasks. Let’s explore when Python might need backup.
#
# - Concurrency limitations: The Global Interpreter Lock (GIL) restricts true parallel threading. Only one thread executes Python bytecode at a time, even on multi-core CPUs. Workaround is to use multiprocessing instead of threading - spawn separate Python processes (each with its own GIL) to leverage multiple cores.
#
# - Pure Python performance lags for heavy computation. This can be mitigated by integrating C extensions (Cython) or using optimized libraries like NumPy (written in C/Fortran).
#
# - Startup Latency: Interpreter initialization creates millisecond-scale delays — problematic for systems that need to respond very quickly (microsecond-response systems).
#
# - Mobile Development Gap: Limited native support for iOS/Android ecosystems. The main reason for this is that Python's design prioritizes flexibility over mobile constraints.

# %% [markdown]
# ###  Beginners Love Python because
# - Python has gentle learning curve: You'll write useful programs on day one
# - Python code is easily readable: You can understand your own code weeks later
# - Python gives you instant feedback: You can see results immediately without waiting fro the code to be compiled and then running it.
# - Python's got one of the best support communities out there. Huge open-source ecosystem, docs for everything, and tons of users happy to help beginners
#
# ### Why Scientists and Engineers Love It
# - Python offers clean data workflows: Tools like Pandas and NumPy transform raw data into actionable insights-
# - Python Visualize clearly: You can build charts and graphs quickly with Matplotlib/Seaborn with just a few lines of code
# - Simplify repetitive work: Quickly create scripts to handle routine tasks while you focus on discovery
# - Python is proven in practice: It is used by NASA, Google, and researchers worldwide.
#
# ### How Python Compares to Other Languages?
# | Language | Best For | Learning Experience | Real-World Analogy |
# |---|---|---|---|
# |Python| Data analysis, beginners	   | Like learning with training wheels	| Comfortable SUV - easy to drive anywhere |
# |C++   | Game engines, performance	   | Like building a car engine	| Race car - powerful but complex|
# Java   | Large business systems	       | Like assembling furniture	| Minivan - practical but lots of parts|
# |R	   | Statistics, academic research | Like using a scientific calculator	| Lab equipment - specialized|

# %% [markdown]
# ## 4. Getting to Know the Dataset
#
# Now that we’ve explored the key advantages and limitations of Python — particularly its strengths in data analysis, visualization, and ease of use — it’s time to look at how we’ll apply these features in practice during this workshop.
#
# To ground our learning in a realistic and relevant context, we’ll use a simplified example from clinical research: a synthetic dataset from a fictional clinical trial assessing the therapeutic effect of a novel drug. This case study will guide us through the core steps of data analysis in Python — from data import to statistical validation and result visualization — mirroring the kinds of tasks researchers often face in real-world biomedical projects.

# %% [markdown]
# ## 5. Basic concepts: variables, data types and built-in finctions
#
# Before we begin analyzing data, we'll introduce one of the most fundamental concepts in programming: variables along with other essential building blocks of Python: data types and built-in functions.
#
# These core concepts are necessary for writing any Python code—whether simple or complex—and will serve as the groundwork for everything we do throughout the workshop.
#
# #### 5.1 What is a variable
#
# Let’s start with something simple. We can use python as a command-line calculators to do quick math:

# %%
3 + 5 * 4
# Out:
# 23

# %% [markdown]
# This gives us a single result—but it’s hardcoded, meaning we can’t easily reuse or adapt it. If we wanted to calculate the same expression with different numbers, we’d have to rewrite the entire line each time.
#
# Now, imagine we want to apply this formula — say, a + b * c — to many different sets of numbers. This is where variables become essential. Instead of plugging in fixed values, we assign values to variables like this:

# %%
a = 3  
b = 4  
c = 5  
result = a + b * c
result
# Out:
# 23

# %% [markdown]
# Not only does this make the code more readable, but it also makes it easy to change the values of a, b, and c and reuse the formula as many times as we need. This is a key benefit of using variables: they let us apply the same logic to different data with minimal effort.
#
# From this example, you can already see that a variable is simply a name that refers to a value.
#
# Let’s look at another example: suppose we have a patient who weighs 60 kilograms. We can store this value in a variable called weight_kg

# %%
weight_kg = 60

# %% [markdown]
# Now, Python will remember that weight_kg holds the value 60. Instead of repeating the number or redoing the calculation each time, we can simply use weight_kg whenever we need to refer to the patient’s weight.
#
# **A Few Rules for Naming Variables:**
# - You can use **letters**, **digits**, and **underscores (_)**, but the name ***can’t*** start with a ***digit***.
# - Variable names are case-sensitive, so **weight** and **Weight** are two different things.
#
# For example:
# - **weight0** is valid, but **0weight** isn’t.
# - **weight_kg** is different from **Weight_kg**.

# %% [markdown]
# ### 5.2 Types of Data in Python
# Python can work with different types of data and understanding them is essential to writing effective programs.
# Some of the most common types are:
#
# - int **Integers** (whole numbers like 1, 2, 100)
# - float **Floating point numbers** (numbers with decimals like 2.5, 60.3)
# - str **Strings** (text like "Hello", "001")
# - complex **Complex numbers** (2 + 3j)
# - bool **Boolean** (True/False)
#
# Python automatically assigns a data type to a value based on how it's written.
#
# For example, let’s say we want to store a patient’s weight. If the weight is exactly 60 kilograms, we can use an integer:

# %%
weight_kg = 60
weight_kg
# Out:
# 60

# %% [markdown]
# But if we want to be more precise, like 60.3 kilograms, we can use a floating point number:

# %%
weight_kg = 60.3  # Explicit float
weight_kg
# Out:
# 60.3

# %% [markdown]
# You can also convert between types if needed. For example we can convert integer variable to float or enforce variable to be float using built-in float() function.

# %%
weight_kg = 60
weight_kg
# Out:
# 60

# %%
weight=float(weight)
weight
# Out:
# 60.0

# %% [markdown]
# #### Strings
# To store text, such as a unique ID for each patient, we use strings. Strings are surrounded by single or double quotes:

# %%
patient_id = '001'
patient_id
# Out:
# '001'

# %% [markdown]
# In Python, there is no functional difference between single quotes (') and double quotes (") when defining strings. Both can be used interchangeably.
#
# #### When to choose one over the other:
# The choice usually comes down to readability or avoiding escape characters. For example:
#
# If your string contains a single quote, use double quotes to avoid escaping:

# %%
sentence = "It's a beautiful day"
print(sentence)
# Tell python that the quote in "It's" is a literal quote - not the end of the string.  
sentence = 'It\'s a beautiful day'
print(sentence)
# Want to define a string with both types of quotes?
sentence = "It\'s a \"beautiful\" day"
print(sentence)
# Out:
# It's a beautiful day
# It's a beautiful day
# It's a "beautiful" day

# %% [markdown]
# NOTE: 'sentence' prints representation of string, 'print(sentence)' shows the actual string!

# %% [markdown]
# ### 5.3 Using Variables in Python
# Once we store data in variables, we can use those variables to do calculations.
#
# For example, if we want to convert the patient’s weight to pounds, we can use this formula:

# %%
weight_lb = 2.2 * weight_kg
weight_lb
# Out:
# 165.0

# %% [markdown]
# This takes the weight in kilograms and multiplies it by 2.2 to convert it to pounds.
#
# We can also change a string by adding more text to it. For instance, we might want to label the patient ID:

# %%
patient_id = 'inflam_' + patient_id
patient_id
# Out:
# 'inflam_001'

# %% [markdown]
# Now the patient ID would look like this: inflam_001.

# %% [markdown]
# ### 5.4 Built-in Python Functions
# Python has built-in functions that perform common tasks. One very useful function is print(), which shows information on the screen. For example:

# %%
print(weight_lb)
print(patient_id)
# Out:
# 165.0
# inflam_001

# %% [markdown]
# When we use a function like **print()**, the parentheses are mandatory: They tell Python: "Execute this function now!"
# No parentheses → Python treats print as an object (won't run). Try it youself!
# Arguments go inside the parentheses:
# Arguments are the input data you feed to the function.
# For print(weight_lb):
# weight_lb is the argument specifying a variable to display.
#
# You can also use multiple arguments - separate them with commas to display more than one thing at a time. For example, to print both the patient ID and the weight in kilograms, we write:

# %%
print(patient_id, 'weight in kilograms:', weight_kg)
# Out:
# inflam_001 weight in kilograms: 75.0

# %% [markdown]
# Key Rules:
#
# - Always use ( ) after the function name
# - Arguments are the data you want to process
# - Commas separate multiple arguments
# - No limit on arguments (if syntax is correct)
#
# You can see the full list of built-in functions in Python’s official docs: https://docs.python.org/3/library/functions.html

# %% [markdown]
# ### 5.5 Checking Data Types
# We can also check what kind of data we’re working with. For example, to see if a variable is a string or a floating point number, we use the **type()** function:

# %%
print(type(weight_kg))
print(type(patient_id))
# Out:
# <class 'float'>
# <class 'str'>

# %% [markdown]
# ### 5.6 Arithmetic with Variables
# Python can evaluate mathematical expressions directly inside print(). For example, you can convert kilograms to pounds and print the result with one function call:

# %%
print('weight in pounds:', 2.2 * weight_kg)
# Out:
# weight in pounds: 165.0

# %% [markdown]
# Inside print(), Python does math before printing. When you put a math expression in print(), Python automatically calculates the result first, then shows the answer. Python reads inside-out: When it sees print( [...] ), it first evaluates everything inside the parentheses.

# %% [markdown]
# Notice that this doesn’t change the value of weight_kg. If we print weight_kg again, it will still be 60.3.

# %%
print('Weight in kg: ', weight_kg )
# Out:
# Weight in kg:  75.0

# %% [markdown]
# In Python, variables are like labels attached to values. Changing a variable's value is called reassignment
# To change the value of a variable, we have to assign it a new value (it is called called reassignment) and: For example, if the patient’s weight changes to 65 kilograms we can overwrite with new value:

# %%
weight_kg = 65.0
print('weight in kilograms is now:', weight_kg)
# Out:
# weight in kilograms is now: 65.0

# %% [markdown]
# #### Calculating new value from old
# When we are changing numeric values we can calculate new value from old:

# %%
weight_kg = weight_kg + 10
print('weight in kilograms is now:', weight_kg)
# Out:
# weight in kilograms is now: 75.0

# %% [markdown]
# #### Shortcut reassignment operators
# In Python, shortcut reassignment operators let you update the value of a variable using a shorter, more convenient syntax:

# %%
x = 10
x += 5      # x is now 15
x *= 2      # x is now 30
x //= 7     # x is now 4 (floor division)
x
# Out:
# 4

# %% [markdown]
# These shortcuts make your code easier to read when updating values based on their current state.

# %% [markdown]
# Python allows you to assign variables at once:

# %%
x, y = 5, 10  # x=5, y=10
print(x,y)
x, y = y, x   # Swap values → x=10, y=5
print(x,y)
# Out:
# 5 10
# 10 5

# %% [markdown]
# Python lets variables change types dynamically:

# %%
value = 100            # Integer
print(value)           # Output: 100

value = "One hundred"  # Now a string
print(value)           # Output: One hundred

value = 10 + 4j        # Now a complex
print(value)           # Output: (10+4j)
# Out:
# 100
# One hundred
# (10+4j)

# %% [markdown]
# ---
# #### Exercise 1.  (5 min)
#
# A. What values do the variables *mass* and *age* have after each of the following statements? Test your answer by executing the lines.
#   - mass = 47.5
#   - age = 122
#   - mass = mass * 2.0
#   - age = age - 20

# %% [markdown]
# B. What does the following code print out?

# %%
first, second = 'Grace', 'Hopper'
third, fourth = second, first
print(third, fourth)
# Out:
# Hopper Grace

# %% [markdown]
# C. What are the data types of the following variables?
#   - planet = 'Earth'
#   - apples = 5
#   - distance = 10.5
#   ---

# %% [markdown]
# ### 6. Introduction to Python Libraries.
#
# Python comes with basic tools for things like adding and subtracting. But sometimes, we need more advanced tools for special tasks, like working with large groups of numbers. This is where ***libraries*** come in. Libraries (also called modules or packages) are collections of reusable code that solve common problems, so you don't have to write everything from scratch. Think of them as specialized toolkits for different tasks!
#
# It's best practice to load libraries only when you need them. Why?
# Loading a library takes time and memory. If you import many libraries at the start — especially ones you don’t end up using — it can slow down your program's startup time and increase resource usage unnecessarily.
#
# To begin working with the clinical trial data, we first need to load it into Python. For loadong data as well as for data analysis, we’ll use a library called NumPy, which stands for Numerical Python. This library is commonly used when working with large sets of numbers, especially for mathematical operations involving arrays or matrices. If you’re dealing with numerical data and want to perform efficient calculations, NumPy is the right tool. Under the hood, NumPy is implemented in highly optimized C code, which makes its array operations much faster than pure Python loops.
#
# To tell Python that we’d like to start using NumPy, we need to import it:

# %%
import numpy as np

# %% [markdown]
# This import numpy and gives it the **np** nickname.

# %% [markdown]
# ### 7. Loading Data

# %% [markdown]
# After importing NumPy, we can load our data from a file (like a CSV file) using a specific function called **loadtxt()**. This function is used to load data from a text file into a NumPy array. It’s a simple and efficient way to read structured numeric data such as CSV or tab-delimited files if the data is purely numeric and clean (does not have missing or not numeric values).
#
# For real-world mixed-type or messy files, use np.genfromtxt() which is more powerful and flexible. It can handle missing values, mixed data types, and files with headers.

# %%
np.loadtxt(fname='data/test_data.csv', delimiter=',')
#np.genfromtxt(fname='../trial.csv', delimiter=',')
# Out:
# array([[110.,  85., 113., ...,  35.,  60.,  62.],
#        [ 99.,  84.,  82., ...,  32.,  64.,  58.],
#        [ 97., 109., 109., ...,  52.,  32.,  29.],
#        ...,
#        [ 93., 102.,  98., ...,  71.,  34.,  57.],
#        [ 97., 104.,  96., ...,  57.,  66.,  45.],
#        [ 94.,  82.,  84., ...,  63.,  40.,  47.]], shape=(200, 60))

# %% [markdown]
# - ***fname*** specifies the name of the file we want to load.
# - ***delimiter*** tells the function how the values are separated in the file (e.g., by commas).
#
# Running this command will read in the contents of the file and output the data as an array. An array looks like a table of numbers.

# %% [markdown]
# As we haven’t told it to do anything with the function’s output, the notebook displays it. In this case, that output is the data we just loaded. By default, only a few rows and columns are shown and trailing zeros are not printed.
#
# Our call to numpy.loadtxt() read the file, but it didn’t store the data in memory. To keep the data for later use, we need to assign the resulting array to a variable. Just like assigning a single value to a variable, we can assign an entire array using the same assignment syntax.
# Let’s re-run np.loadtxt() and save the returned data:

# %%
data = np.loadtxt(fname='../trial.csv', delimiter=',')

# %% [markdown]
# This statement doesn’t produce any output because we’ve assigned the output to the variable data. If we want to check that the data has been loaded, we can print the variable’s value:

# %%
print(data)
# Out:
# [[110.  85. 113. ...  35.  60.  62.]
#  [ 99.  84.  82. ...  32.  64.  58.]
#  [ 97. 109. 109. ...  52.  32.  29.]
#  ...
#  [ 93. 102.  98. ...  71.  34.  57.]
#  [ 97. 104.  96. ...  57.  66.  45.]
#  [ 94.  82.  84. ...  63.  40.  47.]]

# %% [markdown]
# ### 7.1 Understanding the Data

# %% [markdown]
# Now that the data is stored in memory, we can begin working with it. First, let’s check what type of object our variable data refers to:

# %%
# Check what type of object our variable data refers to
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# The output tells us that data currently refers to an N-dimensional array, a data structure provided by the NumPy library.
# The rows are the individual patients, and the columns are their daily inflammation measurements.
#
# Python's type() function only confirms an object is a NumPy array (numpy.ndarray). How do we determine the data type of the elements inside a NumPy array? We use the .dtype attribute of the array.

# %%
# What is the data type of the elements inside the array? 
print(data.dtype)
# Out:
# float64

# %% [markdown]
# Standard NumPy arrays are homogeneous containers designed for high-performance numerical computing. They cannot store elements of different data types.

# %% [markdown]
# We can view the shape of a NumPy array, using the .shape attribute.  It returns a tuple (an ordered list of objects) that reveals the dimensions of your array.

# %%
# Check the dimensions of the array
print(data.shape)
# Out:
# (200, 60)

# %% [markdown]
# When we examine the data array we see it contains 200 patient rows and 60 daily measurement columns. When we create a numpy array alongside these numerical values, array attributes are created. Attributes are descriptive properties that characterize the array's structure. Attributes like .shape or .dtype describe essential properties of our data array.
#
# We access attributes using a dot, just like we call functions that belong to an object. For instance, we might use `numpy.mean(data)` to compute the average.
#
# The dot (`.`) connects the object (like `data` or `numpy`) to its attributes or methods, similar to how a last name connects to a family — it shows what belongs to what.

# %% [markdown]
# ### 7.2 Accessing Data in NumPy Arrays
# #### Basic Indexing (0-Based): Accessing individual elements.
#
# To retrieve a single value from a 2D array like our dataset, we use double-indexing in square brackets. This is similar to how we refer to an element in a math matrix. Since our data has two dimensions, we need to use two indices (row and column) to access one exact value.

# %%
print('first value in data:', data[0, 0])
# Out:
# first value in data: 110.0

# %%
print('middle value in data:', data[99, 29])
# Out:
# middle value in data: 102.0

# %% [markdown]
# In Python, arrays are indexed starting from 0, unlike some languages (Fortran, R) that start from 1. For example, **data[29, 19]** accesses row 30, column 20, but **data[0, 0]** refers to the first element.
#
# Why Counting Starts at Zero? In computer science, counting from zero isn't arbitrary - it directly reflects how computers physically store data. Arrays reside in contiguous memory blocks, where each element's location is calculated as:
#
# Base Address + (Index × Element Size)
#
# The first element sits exactly at the base address, requiring zero offset (Index = 0). This zero-based indexing originated in the C language and was adopted by Python. One of the main reasons is that it maintains interoperability with C libraries and feels natural to programmers familiar with lower-level languages. >90% of mainstream languages use 0-based indexing, making it the de facto standard for software development, systems programming, and web technologies.
#
# With "zero-based" indexing if an array has dimensions M×N, the valid indices range from 0 to M-1 for rows and 0 to N-1 for columns.

# %% [markdown]
# #### Slicing: Accessing subarrays by specifying slices.
# - Extract subarrays with `start:stop:step` syntax.
# An index pair like [30, 20] selects a single element of an array, but we can select whole sections as well. For example, we can select the first ten days (columns) of values for the first four patients (rows) like this:

# %%
print(data[0:4, 0:10])
# Out:
# [[110.  85. 113.  92.  95.  99.  99.  84.  96.  94.]
#  [ 99.  84.  82.  77. 116. 103.  92. 110. 109.  89.]
#  [ 97. 109. 109. 100. 113. 101. 117. 112.  96.  85.]
#  [ 96.  83.  97.  80. 102. 110.  98.  85. 119. 113.]]

# %% [markdown]
# The slice 0:4 means, “Start at index 0 and go up to, but not including, index 4”. Again, the up-to-but-not-including takes a bit of getting used to, but the rule is that the difference between the upper and lower bounds is the number of values in the slice.

# %% [markdown]
# Also, we don’t have to start slices at 0:

# %%
print(data[5:10, 0:10])
# Out:
# [[102. 104.  84. 116. 109. 108.  90.  87. 109. 103.]
#  [102. 103.  84. 114. 104. 104.  81. 110. 118. 115.]
#  [103.  88.  92. 103. 111. 111. 107.  87.  90. 111.]
#  [100.  80. 117.  79.  90.  88.  90.  85. 109.  83.]
#  [ 94.  98. 113.  98. 114. 116.  98. 104. 112.  83.]]

# %% [markdown]
# We also don’t have to include the upper and lower bound on the slice. If we don’t include the lower bound, Python uses 0 by default; if we don’t include the upper, the slice runs to the end of the axis, and if we don’t include either (i.e., if we use ‘:’ on its own), the slice includes everything:

# %%
print(data[:3, 56:])
# Out:
# [[33. 35. 60. 62.]
#  [72. 32. 64. 58.]
#  [59. 52. 32. 29.]]

# %% [markdown]
# The above example selects rows 0 through 2 and columns 56 through to the end of the array.

# %% [markdown]
# ____
# #### **Note: You can also slice Strings**
# A section of an array is called a slice. We can take slices of character strings as well:

# %%
element = 'oxygen'
print('first three characters:', element[0:3])
print('last three characters:', element[3:6])
# Out:
# first three characters: oxy
# last three characters: gen

# %% [markdown]
# # Exercise 2. String Slicing (10 min)
# Given the string word = 'algorithm'
#
# ```
# Indices:    [0] [1] [2] [3] [4] [5] [6] [7] [8]
# Characters:  a   l   g   o   r   i   t   h   m
# ```
#
# A. Slice the string:
#   - What is word[:4] ?
#   - What is word[5:] ?
#   - What is word[3:6] ?
#   - What is word[2::3] ?
#
# B. Negative Indexing
#   - What is word[-1] ?
#   - What is word[-3] ?
#   - What is word[-4:-1] ?
#
# C. Explain these operations:
#
# 1. word[2:-2]
#    - What substring does it return?
#    - How do positive and negative indices interact?
# 2. word[::-1]
#    - What does this operation do
#    - What does -1 mean in the step position?

# %%
# Verification template
word = "algorithm"
print("A1:", word[:4])     # ?
print("A2:", word[5:])     # ?
print("A3:", word[3:6])    # ?
print("A4:", word[2::3])   # ?
print("B1:", word[-1])     # ?
print("B2:", word[-3])     # ?
print("B3:", word[-4:-1])  # ?
print("C1:", word[2:-2])   # ?
print("C2:", word[::-1])   # ?
# Out:
# A1: algo
# A2: ithm
# A3: ori
# A4: gim
# B1: m
# B2: t
# B3: ith
# C1: gorit
# C2: mhtirogla

# %% [markdown]
# ___

# %% [markdown]
# ### 8. Analyzing the data.
# ### 8.1 Case study - assessing the therapeutic effect of the treatment.
# Now that we've covered Python fundamentals such as variables, data types, and arrays, we're ready to apply these tools to real data analysis.
#
# Remember the clinical trial study I mentioned earlier? Let’s now take a closer look at this case study and explore it in more detail.
#
# Imagine our colleague, has developed a novel drug that he claims significantly reduces arthritic inflammation within three weeks of starting treatment. To evaluate this claim, we've been given access to anonymized data from a clinical trial designed to test the drug’s effectiveness.
#
# The trial followed 60 patients diagnosed with arthritis over a 40-day observation period. The data is organized as a 2D array, where each row represents an individual patient and each column corresponds to a daily measurement. The recorded metric is the Inflammation Severity Index, a numerical value representing the level of inflammatory activity on each day.
#
# Our main analytical goals are to:
#
# - assess the overall effectiveness of the treatment by calculating the mean daily inflammation across all patients.
# - Visualize trends in inflammation over time to see how patients respond throughout the course of the study.
#
# According to the clinical hypothesis, the drug requires approximately 21 days to take full effect following the initial inflammatory event. Therefore, we expect to see:
#
# - A sustained drop in inflammatory markers after Week 3.
# - A statistically significant difference between the early phase (Days 0–20) and the later phase (Days 21–40) of the trial.
#
# Jumping straight into the real dataset can be risky — what if our code has hidden bugs? To build confidence, we'll first apply our code to a  test dataset where we know the expected outcome. Once we're sure everything works correctly, we'll scale up to the real data. And this test data file is the file we have alredy loaded: test_data.csv.
#
# ### 8.2. NumPy's functions
# For our analysis we will be using NumPy's functions. NumPy provides optimized, vectorized functions that operate on entire arrays efficiently. It is using C backend which is typically (100x faster than Python loops).
#
# #### Key Functions
#
# | Category	| Functions |
# | --------- | --------- |
# | Math	| np.sqrt, np.exp, np.sin |
# | Aggregation |	np.sum, np.mean, np.max |
# | Manipulation |	reshape, flatten, transpose |
# | Logic	| np.where, np.logical_and |
# | Linear Algebra |	np.dot, np.linalg.inv |
# | Sets |	np.unique, np.intersect1d |
#
# Let's start them to analyse our clinical tial data. If we want to find the average inflammation for all patients on all days, for example, we can ask NumPy to compute data’s mean value like this:

# %%
print(np.mean(data))
# Out:
# 83.39475

# %% [markdown]
# Here, we are calling the mean() function from the NumPy module.  It is not tied to any particular object and must be explicitly told what data to operate on. In this case, we are passing the variable data as an argument to the mean() function so that it can compute the average of the values it contains. Think of this as: "Tell NumPy to calculate the mean of this data."
#
# Also we can use mean() as a method:

# %%
print(data.mean())
# Out:
# 83.39475

# %% [markdown]
# **data.mean()** is a method that belongs to the *data* object itself. It operates directly on the **data** array, as long as the object (like a NumPy array) supports the .mean() method. In the case of NumPy arrays, this method is already implemented and ready to use. Think of this as: "Ask the array to calculate its own mean."

# %% [markdown]
# _______________________________________________________________________________________________________
# #### **Note: Not all functions require input**
#
# While functions typically use inputs to produce outputs, some functions can return a result without any input at all. For example, retrieving the current time doesn't require any arguments — it's simply a request for information that the system already knows.

# %%
import time
print(time.ctime())
np.random.rand()
# Out:
# Tue Jun 24 14:21:10 2025
# 0.5605603472982661

# %% [markdown]
# For functions that don’t take in any arguments, we still need parentheses (()) to tell Python to go and do something for us.

# %% [markdown]
# _______________________________________________________________________________________________________

# %% [markdown]
# Now, let's use three NumPy functions to find important values about our data: the maximum value, minimum value, and the standard deviation. Instead of writing separate lines of code for each, we can use a Python feature called multiple assignment to do it all in one line.

# %%
maxval, minval, stdval = np.amax(data), np.amin(data), np.std(data)
print('maximum inflammation:', maxval)
print('minimum inflammation:', minval)
print('standard deviation:', stdval)
# Out:
# maximum inflammation: 124.0
# minimum inflammation: 17.0
# standard deviation: 20.697280556573126

# %% [markdown]
# - **numpy.amax(data)** finds the largest number in the dataset and assigns it to maxval.
# - **numpy.amin(data)** finds the smallest number and assigns it to minval.
# - **numpy.std(data)** calculates the standard deviation, which tells us how spread out the numbers are, and assigns it to stdval.

# %% [markdown]
# When analyzing data, we often want to focus on specific parts of it. For example, we might want to find the maximum inflammation for a single patient or the average inflammation across all days. To do this, we can temporarily extract just the portion of data we need and then perform the desired calculation.

# %% [markdown]
# ### 8.3 Extracting and Analyzing One Patient’s Data
#
# Let's select all the inflammation data for the first patient and assign it to the variable patient_0:

# %%
patient_0 = data[0, :]  # Extract the first row (patient 0), all columns (days)
print('maximum inflammation for patient 0:', np.amax(patient_0))
# Out:
# maximum inflammation for patient 0: 119.0

# %% [markdown]
# - data[0, :] selects all the values from row 0 (patient 0).
#     - 0 on the first axis (rows) means we want patient 0's data.
#     - : on the second axis (columns) means we want all the days.
# - np.amax(patient_0) calculates the maximum inflammation for that patient.

# %% [markdown]
# Instead of storing the row in a separate variable, we can perform operations directly on a slice of the data.

# %%
print('maximum inflammation for patient 2:', np.amax(data[2, :]))
# Out:
# maximum inflammation for patient 2: 117.0

# %% [markdown]
# - data[2, :] selects all the data for patient 2 (the third patient).
# - numpy.amax(data[2, :]) calculates the maximum inflammation directly.
#
# When you extract part of a NumPy array using slicing you are not creating a brand-new array. Instead, you're creating a view of the original array. A view is a lightweight object that refers to the same data in memory as the original array. It lets you look at or work with a portion of the data without copying it. It’s fast and memory-efficient, since no new data is created. It also avoids the need to create a separate named variable, making the code more concise.

# %% [markdown]
# ### 8.4 Summarizing the data (aggregation)
#
# When working with 2D NumPy arrays (like matrices or datasets where rows = observations and columns = features or time points), we often want to summarize the data—by computing things like totals, means, minimums, or maximums. This process is called aggregation.
#
# For our dataset we may want to calculate values for each patient (such as the maximum inflammation per patient) or for each day (such as the average inflammation across all patients). To do this, we perform calculations across rows or columns of our data.
#
# In NumPy, we use a special argument called axis to tell the function which direction to operate in:
#
# - axis=1 → operate across columns (i.e. calculate a value for each row, such as per patient)
# - axis=0 → operate down rows (i.e. calculate a value for each column, such as per day)
#
# This allows us to easily summarize large datasets in a meaningful way, depending on whether we’re focused on individual cases (rows) or time points/measurements (columns).

# %% [markdown]
# ### Example 1: Maximum Inflammation Per Patient
#
# To calculate the maximum inflammation for each patient (looking across all the days), we do this:

# %%
print(np.amax(data, axis=1).shape)
# Out:
# (200,)

# %% [markdown]
# This gives us an array of 200 values, and we have 200 patients (200 rows), therefore it outputs the maximum value accross all days per patient.

# %% [markdown]
# #### Example 2: Average Inflammation Per Da
#
# To calculate the average inflammation per day (looking at all patients), we do this:

# %%
print(np.mean(data, axis=0))
# Out:
# [ 95.47   95.065  96.005  95.155  98.29   98.745  97.435 100.26   99.995
#   99.965  99.58   99.46   99.025  99.005  98.355  99.53   98.245  99.26
#   98.035  97.67   96.765  96.77   97.225  95.825  95.87   93.75   95.685
#   94.98   91.215  91.525  90.345  89.745  90.235  88.245  87.38   84.18
#   83.205  81.655  82.07   79.05   78.72   74.51   74.185  70.9    70.425
#   68.02   66.64   65.855  63.34   62.465  59.18   57.855  55.37   55.655
#   54.565  53.7    52.245  50.86   49.64   49.285]

# %% [markdown]
# This array contains the average inflammation per day for all patients. To confirm, we check the shape of this data:

# %%
print(np.mean(data, axis=0).shape)
# Out:
# (60,)

# %% [markdown]
# This tells us we have an array of length 60, which represents the 60 days in our dataset.

# %% [markdown]
# #### Example 3: Average Inflammation Per Patient
#
# To calculate the average inflammation per patient (looking across all days), we do this:

# %%
print(np.mean(data, axis=1))
# Out:
# [85.65       84.3        85.43333333 83.76666667 83.98333333 83.91666667
#  83.86666667 80.91666667 85.31666667 84.48333333 86.65       83.48333333
#  83.51666667 80.78333333 82.98333333 84.35       85.58333333 84.05
#  80.76666667 83.88333333 84.96666667 82.23333333 85.88333333 85.45
#  84.9        85.48333333 81.98333333 84.63333333 84.68333333 84.63333333
#  84.4        83.61666667 81.91666667 82.83333333 82.91666667 85.33333333
#  83.13333333 83.06666667 83.9        84.58333333 84.08333333 85.38333333
#  81.43333333 84.2        86.31666667 80.23333333 82.66666667 81.08333333
#  82.68333333 82.75       84.51666667 82.75       82.56666667 83.86666667
#  82.38333333 85.13333333 87.48333333 82.2        86.15       85.65
#  81.95       84.13333333 82.33333333 81.         82.93333333 81.41666667
#  82.15       82.78333333 81.68333333 81.98333333 83.28333333 86.93333333
#  81.36666667 81.2        85.01666667 82.98333333 83.71666667 84.1
# ...

# %% [markdown]
# ### 8.5 Change in Inflamation
# In our dataset, each row shows data for a single patient over 60 days. Finding the change in inflammation over time is an important quantity. How do we measure it? To measure how inflammation changes from one day to the next, we can use the `np.diff()` function.
#
# The np.diff() function computes the difference between consecutive elements in an array. It's useful for detecting changes over time.
#
# #### Example: Change in Inflammation for One Patient
#
# Let’s look at the inflammation for patient 3 during the first week:

# %%
patient3_week1 = data[2, :7]  # Days 1 to 7 for patient 3
print(patient3_week1)
# Out:
# [ 96.  83.  97.  80. 102. 110.  98.]

# %% [markdown]
# Now, let’s calculate the difference between each day’s inflammation:

# %%
np.diff(patient3_week1)
# Out:
# array([-13.,  14., -17.,  22.,   8., -12.])

# %% [markdown]
# The function calculates the following:
# - 83 - 96
# - 97 - 83
# ...
# - 98 - 110
#
# Notice that the result has one fewer value because we are measuring differences between values.

# %% [markdown]
# ___
# ### Check your Understanding
# #### Applying np.diff() to the whole dataset
#
# If you want to apply `np.diff()` to a multi-dimensional array (like our dataset), you can specify which direction (axis) to calculate the differences.
#
# - axis=1 will compute the differences across days for each patient (horizontally).
# - axis=0 will compute the differences across patients for each day (vertically).
#
# *Try it out!*

# %%
print(np.diff(data, axis=1))
# Out:
# [[-25.  28. -21. ...   2.  25.   2.]
#  [-15.  -2.  -5. ... -40.  32.  -6.]
#  [ 12.   0.  -9. ...  -7. -20.  -3.]
#  ...
#  [  9.  -4.   0. ...  34. -37.  23.]
#  [  7.  -8.  17. ... -13.   9. -21.]
#  [-12.   2.  17. ...  -5. -23.   7.]]

# %% [markdown]
# ___

# %% [markdown]
# ## 9. Visualizing data
# The mathematician Richard Hamming once said, *“The purpose of computing is insight, not numbers,”* and the best way to develop insight is often to visualize data. Visualization deserves an entire lecture of its own, but we can explore a few features of Python’s *matplotlib* library here.
#
# In Python, we use a library called **matplotlib** for creating plots and graphs. Specifically, we use the **pyplot** module to make various kinds of charts, such as heat maps and line graphs.

# %% [markdown]
# Let's start by importing our matplotlib library and pyplot module using a nickname *plt*:

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# #### 9.1 Heatmaps
# Now, let's try plotting a heatmap. A heat map is a graphical representation of data where individual values are represented as colors. In our case, we want to visualize inflammation data to see trends or patterns in patient conditions over time:

# %%
# Create a heat map using the data
image = plt.imshow(data)
plt.show()

# %% [markdown]
# - imshow() 2D displays 2D array it as a grid where each cell's color corresponds to the value in that cell.
# - the color gradient helps us quickly see patterns in the data.

# %%
# add colorbar and customize colormap
image = plt.imshow(data, cmap='magma')
plt.colorbar(image)
plt.show()

# %% [markdown]
# As we can see, the inflammation severity index remained relatively stable until approximately day 20 after the start of treatment, which aligns with the trial design. After that point, the index began to decline, indicating that the treatment is having an effect.

# %% [markdown]
# #### 9.2. Plotting data averaged across patients.
# Of course, as expected, the data is noisy due to fluctuations in individual patient responses. To gain a clearer picture of the treatment’s overall effect, we can calculate the average inflammation per day across all patients.

# %%
ave_inflammation = np.mean(data, axis=0)

# Plot the result
ave_plot = plt.plot(ave_inflammation)
plt.show()

# %% [markdown]
# Here, we calculated the average inflammation per day across all patients and stored the result in the variable ave_inflammation. We then used matplotlib.pyplot to generate a line graph of those values. The result supports our earlier visual observations: a slight upward trend in inflammation levels until around day 20 after the start of treatment.
#
# However, a good data scientist doesn’t rely solely on averages — so let’s explore two additional statistics for a more complete picture.

# %%
max_plot = plt.plot(np.amax(data, axis=0))
plt.show()

# %%
min_plot = plt.plot(np.amin(data, axis=0))
plt.show()

# %% [markdown]
# As we can see, both the maximum and minimum values follow a similar pattern to the average, which is expected when most or all patients respond to the treatment. If the maximum values did not decrease over time, this might indicate that a subset of patients did not respond to the therapy. On the other hand, if the minimum values were low from the very beginning of the trial, it could suggest that some patients showed little or no inflammation and perhaps should not have been included in the study. This successful alaysis id the test datset also indicates that our software is working correctly and we can proceed with the analysis of the new trial we are interested in.
#
# The maximum value rises and falls linearly, while the minimum seems to be a step function.
#
# A step function for the min graph signals that the number of patients with zero inflammation is not consistent throughout the trial, showing sudden shifts in the inflammation levels for some patients. A step function in the min graph is unlikely to support Dr. Maverick's claim that the drug reduces inflammation gradually over 3 weeks. Dr. Maverick suggests that the inflammation should decrease steadily over time, which would likely result in a smoother downward trend in the min graph, rather than sudden jumps.
#
# For the data to support PI's claims, the max should start high and then decrease after the drug is given. This would show that the highest inflammation counts drop over time. Additionally, there should be at least one patient with no inflammation each day during the trial.
#
# Neither trend seems particularly likely, so either there’s a mistake in our calculations or something is wrong with our data. This insight would have been difficult to reach by examining the numbers themselves without visualization tools.

# %% [markdown]
# ### 10. Grouping plots
# When analyzing data, it’s often useful to visualize multiple related aspects side by side for easy comparison. Python’s Matplotlib library offers a powerful way to group multiple plots into a single figure, allowing you to present and interpret different views of your data simultaneously. This technique is particularly useful when comparing statistics like averages, maximum values, and minimum values over time, which can be visualized together in a neat layout.
#
# In this example, we’ll explore how to use subplots in Matplotlib to create a figure containing three different plots: the average inflammation, maximum inflammation, and minimum inflammation over a period of 40 days for all patients in a clinical trial.
#
# We will use Figures and Subplots. A figure is the entire canvas or window where one or more plots are drawn. Think of it like a blank sheet of paper where visualizations are arranged.
#
# You usually don't need to call `figure()` explicitly if you're using `subplots()` or `plot()` methods directly — Matplotlib will handle it for you. However, if you want to specify the canvas size, you need to call `figure()` and tell it what size do you want (width, height)
#
# Once you have set up your canvas you can create subplots in it. A figure can contain one or multiple subplots arranged in rows and columns. You add subplots to a figure using the `add_subplot()` method which takes nrows, ncols and index:
#
# `axes1 = fig.add_subplot(nrows, ncols, index)`
#
# This gives you an `axis` object — the actual plot area where you draw lines, bars, etc.

# %%
# Create a figure and specify the overall size
fig = plt.figure(figsize=(10.0, 3.0))
# Create three subplots in a 1 row x 3 columns grid
axes1 = fig.add_subplot(1, 3, 1)  # First subplot
axes2 = fig.add_subplot(1, 3, 2)  # Second subplot
axes3 = fig.add_subplot(1, 3, 3)  # Third subplot

# Plot average inflammation on the first subplot
axes1.set_ylabel('average')  # Set the label for y-axis
axes1.plot(np.mean(data, axis=0))  # Plot the average inflammation per day

# Plot maximum inflammation on the second subplot
axes2.set_ylabel('max')  # Set the label for y-axis
axes2.plot(np.amax(data, axis=0))  # Plot the maximum inflammation per day

# Plot minimum inflammation on the third subplot
axes3.set_ylabel('min')  # Set the label for y-axis
axes3.plot(np.amin(data, axis=0))  # Plot the minimum inflammation per day

# Adjust the layout so plots don't overlap
fig.tight_layout()

# Save the figure as a PNG file
plt.savefig('inflammation.png')

# Display the figure
plt.show()

# %% [markdown]
# - **fig = plt.figure(figsize=(10.0, 3.0))**: Creates a new figure with dimensions 10x3 inches.
#
# - **axes1 = fig.add_subplot(1, 3, 1), axes2 = fig.add_subplot(1, 3, 2), axes3 = fig.add_subplot(1, 3, 3)**: Creates three subplots in a 1-row, 3-column grid.
#
# - **axes1.plot(np.mean(data, axis=0))**: Plots the average inflammation per day on the first subplot.
#
# - **axes2.plot(np.amax(data, axis=0))**: Plots the maximum inflammation per day on the second subplot.
#
# - **axes3.plot(np.amin(data, axis=0))**: Plots the minimum inflammation per day on the third subplot.
#
# - **axes1.set_ylabel('average'), axes2.set_ylabel('max'), axes3.set_ylabel('min')**: Labels the y-axes for each subplot.
#
# - **fig.tight_layout()**: Adjusts the spacing between the plots.
#
# - **plt.savefig('inflammation.png') & plt.show()**: Saves the plot as a PNG and displays it.

# %% [markdown]
# ## Exercise: Plotting Average Inflammation with Error Bars ( 10 min)
# In this exercise, you’ll visualize the average inflammation across all patients for each day of the clinical trial. To better understand the variability in patient responses, you'll also include standard deviation as error bars.
#
# ### Instructions:
#
# 1. Compute the average inflammation per day across all patients using np.mean().
# 2. Compute the standard deviation per day using np.std().
# 3. Create a time axis using np.arange(), where each value represents a day.
# 4. Use plt.plot() to draw the line graph of average inflammation.
# 5. Use plt.errorbar() to add error bars representing standard deviation at each point.
# 6. Label the plot and axes appropriately.
# 7. Add a legend to distinguish the line and error bars.
#
# ### Hint:
#
# - Make sure the x axis (days) matches the length of your average and standard deviation arrays.
# - Use ecolor and capsize to style your error bars.
#
# ### Goal:
#
# Your plot should show the average daily inflammation as a smooth curve, with error bars showing day-to-day variation across patients.
#
# Here is the code to start with:

# %%
average = np.mean(data, axis=0)
std = np.std(data, axis=0)
days = np.arange(len(average))
plt.plot(average, label='Average')
plt.errorbar(days, average, std, color='blue', ecolor='lightblue', capsize=3, label='Average ± SD')
plt.title('Daily Average Inflammation with Standard Deviation')
plt.xlabel('Day')
plt.ylabel('Inflammation')
plt.legend()
plt.show()

# %% [markdown]
# ## 11. Python Lists
# In Python, lists are a way to store multiple values together in one place. Unlike NumPy arrays, you don’t need to load any extra libraries to use lists because they are already part of Python. To make a list, just put your values or variables inside square brackets [] and separate them with commas:

# %%
odds = [1, 3, 5, 7]
print('odds are:', odds)
# Out:
# odds are: [1, 3, 5, 7]

# %% [markdown]
# - Each element in a list is assigned an index, starting from 0 for the first element.
# - We can access elements by their index using square bracket notation: `list[index]`.

# %%
print('first element:', odds[0])
print('last element:', odds[3])
print('"-1" element:', odds[-1])
# Out:
# first element: 1
# last element: 7
# "-1" element: 7

# %% [markdown]
# #### Negative Indexing (accessing from the end):
# Yes, we can use negative numbers as indices in Python. When we do so, the index -1 gives us the last element in the list, -2 the second to last, and so on. Because of this, odds[3] and odds[-1] point to the same element here.
#
# #### Lists are mutable
#
# There is one important difference between lists and strings: we can change the values in a list, but we cannot change individual characters in a string. For example:

# %%
names = ['Curie', 'Darwing', 'Turing']  # typo in Darwin's name
print('names is originally:', names)
names[1] = 'Darwin'  # correct the name
print('final value of names:', names)
# Out:
# names is originally: ['Curie', 'Darwing', 'Turing']
# final value of names: ['Curie', 'Darwin', 'Turing']

# %% [markdown]
# This works, but if we try to change an individual character in a string, gives us the following error:

# %%
name = 'Darwin'
name[0] = 'd'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1568], line 2
#       1 name = 'Darwin'
# ----> 2 name[0] = 'd'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Mutable and Immutable Objects
#
# In Python, every value is an object—and each object is either:
# Mutable – it can be changed after it’s created.
# Immutable – it cannot be changed once it’s created.
#
# Mutable object can be changed after it’s created, while immutable object cannot. For example, strings and numbers are immutable, meaning you can't modify them directly. If you try to modify them, a new object is created instead.
# This doesn't mean the variables are constants—it just means their content can’t be altered directly.
#
# Lists and arrays, on the other hand, are mutable, meaning you can modify them after creation. You can change individual elements, append new elements, or reorder the list. For example:

# %%
mild_salsa = ['peppers', 'onions', 'cilantro', 'tomatoes']
hot_salsa = mild_salsa  # hot_salsa points to the same list as mild_salsa
hot_salsa[0] = 'hot peppers'
print('Ingredients in mild salsa:', mild_salsa)
print('Ingredients in hot salsa:', hot_salsa)

# %% [markdown]
# In the example above, both mild_salsa and hot_salsa point to the same list in memory, so when you change hot_salsa, it also affects mild_salsa.
#
# If you want hot_salsa to be independent of mild_salsa, you need to make a copy of the list:

# %%
mild_salsa = ['peppers', 'onions', 'cilantro', 'tomatoes']
hot_salsa = list(mild_salsa)  # creates a copy of mild_salsa
hot_salsa[0] = 'hot peppers'
print('Ingredients in mild salsa:', mild_salsa)
print('Ingredients in hot salsa:', hot_salsa)

# %% [markdown]
# In this case, modifying hot_salsa doesn’t affect mild_salsa because they now refer to different lists.
#
# While modifying data in place is efficient (since it avoids copying large structures), it can make your code harder to follow, especially when multiple variables refer to the same data.
#
# The list() function is a built-in Python constructor used to create a new list object. It can convert other iterable objects into lists or initialize empty lists. For example, you can make a list from a string:

# %%
hello=list('hello')
hello
# Out:
# ['h', 'e', 'l', 'l', 'o']

# %% [markdown]
# ### 12. Nested Lists
#
# Since a list can contain any Python objects, it can  contain other lists.
#
# For example, you could represent the products on the shelves of a small grocery shop as a nested list called veg:

# %% [markdown]
# ![Image of veggies](https://swcarpentry.github.io/python-novice-inflammation/fig/04_groceries_veg.png)
# To store the contents of the shelf in a nested list, you write it this way:

# %%
veg = [['lettuce', 'lettuce', 'peppers', 'zucchini'],
     ['lettuce', 'lettuce', 'peppers', 'zucchini'],
     ['lettuce', 'cilantro', 'peppers', 'zucchini']]

# %% [markdown]
# Here are some visual examples of how indexing a list of lists veg works. First, you can reference each row on the shelf as a separate list. For example, veg[2] represents the bottom row, which is a list of the baskets in that row.

# %% [markdown]
# ![Image of veggies indexes](https://swcarpentry.github.io/python-novice-inflammation/fig/04_groceries_veg0.png)
# Index operations using the image would work like this:

# %%
print(veg[2])
# Out:
# ['lettuce', 'cilantro', 'peppers', 'zucchini']

# %%
print(veg[0])
# Out:
# ['lettuce', 'lettuce', 'peppers', 'zucchini']

# %% [markdown]
# To reference a specific basket on a specific shelf, you use two indexes. The first index represents the row (from top to bottom) and the second index represents the specific basket (from left to right).

# %% [markdown]
# ![Image of veggies indexes2](https://swcarpentry.github.io/python-novice-inflammation/fig/04_groceries_veg00.png)

# %%
print(veg[0][0])
# Out:
# lettuce

# %%
print(veg[1][2])
# Out:
# peppers

# %% [markdown]
# ### 13. Heterogeneous Lists
# Lists in Python can contain elements of different types. For example:

# %%
sample_ages = [10, 12.5, 'Unknown']

# %% [markdown]
# There are many ways to change the contents of lists besides assigning new values to individual elements:

# %%
odds.append(11)
print('odds after adding a value:', odds)
# Out:
# odds after adding a value: [1, 3, 5, 11]

# %%
removed_element = odds.pop(0)
print('odds after removing the first element:', odds)
print('removed_element:', removed_element)
# Out:
# odds after removing the first element: [3, 5, 11]
# removed_element: 1

# %%
odds.reverse()
print('odds after reversing:', odds)
# Out:
# odds after reversing: [11, 5, 3]

# %% [markdown]
# When modifying data in place, it’s important to remember that Python handles lists in a way that can seem counterintuitive. This is because, in Python, variables don’t actually "hold" the list itself, but rather a reference (or pointer) to where the list is stored in memory.
#
# This means that when you assign one list variable to another (e.g., new_list = old_list), you're not creating a new list; you're just pointing both variables to the same list. As a result, if you modify the list using one of the variables, the changes will be reflected in both, which can be unexpected if you're not familiar with how Python handles this.

# %%
odds = [3, 5, 7]
primes = odds
primes.append(2)
print('primes:', primes)
print('odds:', odds)
# Out:
# primes: [3, 5, 7, 2]
# odds: [3, 5, 7, 2]

# %% [markdown]
# To avoid unintended modifications, you can create a copy of the list instead of assigning it directly. This way, changes made to the copied list won't affect the original.

# %%
odds = [3, 5, 7]
primes = list(odds)
primes.append(2)
print('primes:', primes)
print('odds:', odds)
# Out:
# primes: [3, 5, 7, 2]
# odds: [3, 5, 7]

# %% [markdown]
# Subsets of lists and strings can be accessed by specifying ranges of values in brackets, similar to how we accessed ranges of positions in a NumPy array. This is commonly referred to as “slicing” the list/string.

# %%
date = 'Monday 4 January 2016'
day = date[0:6]
print('Day:', day)
# Out:
# Day: Monday

# %% [markdown]
# If you want to take a slice from the beginning of a sequence, you can omit the first index in the range:

# %%
day = date[:6]
print('Omitting beginning index:', day)
# Out:
# Omitting beginning index: Monday

# %% [markdown]
# And similarly, you can omit the ending index in the range to take a slice to the very end of the sequence:

# %%
months = ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec']
sond = months[8:12]
print('With known last position:', sond)
sond = months[8:len(months)]
print('Using len() to get last entry:', sond)
sond = months[8:]
print('Omitting ending index:', sond)
# Out:
# With known last position: ['sep', 'oct', 'nov', 'dec']
# Using len() to get last entry: ['sep', 'oct', 'nov', 'dec']
# Omitting ending index: ['sep', 'oct', 'nov', 'dec']

# %% [markdown]
# ## 14 Loops in Python
# In Python, loops are powerful tools that allow you to repeat a block of code multiple times without explicitly writing it out again.
#
# An example task that we might want to repeat is accessing numbers in a list, which we will do by printing each number on a line of its own.

# %%
odds = [1, 3, 5, 7]

# %% [markdown]
# In Python, a list is basically an ordered collection of elements, and every element has a unique number associated with it — its index. This means that we can access elements in a list using their indices. For example, we can get the first number in the list odds, by using odds[0]. One way to print each number is to use four print statements:

# %%
print(odds[0])
print(odds[1])
print(odds[2])
print(odds[3])
# Out:
# 1
# 3
# 5
# 7

# %% [markdown]
# This is a bad approach for three reasons:
#
# **1) Not scalable**: Imagine you need to print a list that has hundreds of elements. It might be easier to type them in manually.
#
# **2) Difficult to maintain**: If we want to decorate each printed element with an asterisk or any other character, we would have to change four lines of code. While this might not be a problem for small lists, it would definitely be a problem for longer ones.
#
# **3) Fragile**: If we use it with a list that has more elements than what we initially envisioned, it will only display part of the list’s elements. A shorter list, on the other hand, will cause an error because it will be trying to display elements of the list that do not exist.

# %%
odds = [1, 3, 5]
print(odds[0])
print(odds[1])
print(odds[2])
print(odds[3])
# Out:
# 1
# 3
# 5
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1449], line 5
#       3 print(odds[1])
#       4 print(odds[2])
# ----> 5 print(odds[3])
#
# IndexError: list index out of range

# %% [markdown]
# Here’s a better approach: a for loop. This loop iterates over a sequence (like a list or a string) and executes a block of code for each item in that sequence. It’s great for when you know how many times you want to loop.

# %%
odds = [1, 3, 5, 7]
for num in odds:
    print(num)

# %% [markdown]
# The improved version uses a for loop to repeat an operation — in this case, printing — once for each thing in a sequence. The general form of a loop is:

# %%
for variable in collection:
    # do things using variable, such as print

# %% [markdown]
# Using the odds example above, the loop might look like this:
#
#
# ![odd num](https://swcarpentry.github.io/python-novice-inflammation/fig/05-loops_image_num.png)

# %% [markdown]
# In this example, each number (num) in the variable odds is processed one at a time in a loop and printed to the screen. The numbers shown in the diagram indicate the loop cycle during which each value was printed — with 1 being the first cycle and 6 being the last.
#
# We can name the loop variable anything we like. However, the line that starts the loop must end with a colon (:), and all the code that should run inside the loop must be indented.
#
# Unlike many other programming languages, Python does not use an explicit command to mark the end of a loop (such as end for). Instead, Python uses indentation to determine which statements belong to the loop body. Anything indented under the for line is considered part of the loop.
#
# Here’s another loop that repeatedly updates a variable:

# %%
length = 0
names = ['Curie', 'Darwin', 'Turing']
for value in names:
    length = length + 1
print('There are', length, 'names in the list.')

# %% [markdown]
# Let's trace the execution of this loop step by step.
# - the statement incrementing length will be executed three times.
# - 1st time around: length=0, names=Curie, length becomes 1
# - 2nd time around, length=1, names=Darwin, length becomes 2
# - 3nd time around, length=2, names=Turing, length becomes 3
# - the loop finishes and the print function on line 5 tells us our final answer.

# %% [markdown]
# - finding the length of an object is such a common operation that Python has a built-in function to do it called len:

# %%
print(len([0, 1, 2, 3]))
# Out:
# 4

# %% [markdown]
# ***len*** is much faster than any function we could write ourselves, and much easier to read than a two-line loop; it will also give us the length of many other things that we haven’t met yet, so we should always use it when we can.
#
# ### Generate a range of numbers from 1 to N
# Python has a built-in function called range that generates a sequence of numbers. Range can accept 1, 2, or 3 parameters.
#
# - If one parameter is given, range generates a sequence of that length, starting at zero and incrementing by 1. For example, range(3) produces the numbers 0, 1, 2.
# - If two parameters are given, range starts at the first and ends just before the second, incrementing by one. For example, range(2, 5) produces 2, 3, 4.
# - If range is given 3 parameters, it starts at the first one, ends just before the second one, and increments by the third one. For example, range(3, 10, 2) produces 3, 5, 7, 9.
#
# The range() function is important in Python because it provides a memory-efficient way to generate sequences of numbers, which is especially useful for looping. What makes it so efficient? range() returns a special type of object (a range object), not a full list. This makes it very efficient. It you ask range to generate one million numbers it does not actually create a list of one million numbers in memory — it creates an iterable that generates numbers on demand.

# %%
for number in range(1, 4):
    print(number)

# %% [markdown]
# #### Check your Understanding
# Given the following loop:

# %%
word = 'oxygen'
for letter in word:
    print(letter)
# Out:
# o
# x
# y
# g
# e
# n

# %% [markdown]
# How many times is the body of the loop executed?
# - 3 times
# - 4 times
# - 5 times
# - 6 times

# %% [markdown]
# ## 15. Analyzing Data from Multiple Files
# SSo far, we have evaluated our data analysis program using a single test file of clinical trial data. Now we are ready to anayze the whole set of 12 clinical trials provided by the PI.
#
# As a final piece to processing our inflammation data, we need a way to get a list of all the files in our data directory whose names start with inflammation- and end with .csv. The glob library will help us to achieve this:

# %%
import glob

# %% [markdown]
# The glob library contains a function, also called glob, that finds files and directories whose names match a pattern. We provide those patterns as strings: the character * matches zero or more characters, while ? matches any one character. We can use this to get the names of all the CSV files in the current directory:

# %%
print(glob.glob('data/inflammation*.csv'))
# Out:
# ['data/inflammation-05.csv', 'data/inflammation-11.csv', 'data/inflammation-10.csv', 'data/inflammation-04.csv', 'data/inflammation-12.csv', 'data/inflammation-06.csv', 'data/inflammation-07.csv', 'data/inflammation-03.csv', 'data/inflammation-02.csv', 'data/inflammation-01.csv', 'data/inflammation-09.csv', 'data/inflammation-08.csv']

# %% [markdown]
# As these examples show, glob.glob’s result is a list of file and directory paths in arbitrary order. This means we can loop over it to do something with each filename in turn. In our case, the “something” we want to do is generate a set of plots for each file in our inflammation dataset.
#
# If we want to start by analyzing just the first three files in alphabetical order, we can use the sorted built-in function to generate a new sorted list from the glob.glob output:

# %%
filenames = sorted(glob.glob('data/inflammation*.csv'))
for filename in filenames[0:3]:
    print(filename)

    data = np.loadtxt(fname=filename, delimiter=',')
    # Create a figure and specify the overall size
    fig = plt.figure(figsize=(10.0, 3.0))
    # Create three subplots in a 1 row x 3 columns grid
    axes1 = fig.add_subplot(1, 3, 1)  # First subplot
    axes2 = fig.add_subplot(1, 3, 2)  # Second subplot
    axes3 = fig.add_subplot(1, 3, 3)  # Third subplot

    # Plot average inflammation on the first subplot
    axes1.set_ylabel('average')  # Set the label for y-axis
    axes1.plot(np.mean(data, axis=0))  # Plot the average inflammation per day

    # Plot maximum inflammation on the second subplot
    axes2.set_ylabel('max')  # Set the label for y-axis
    axes2.plot(np.amax(data, axis=0))  # Plot the maximum inflammation per day

    # Plot minimum inflammation on the third subplot
    axes3.set_ylabel('min')  # Set the label for y-axis
    axes3.plot(np.amin(data, axis=0))  # Plot the minimum inflammation per day

    # Adjust the layout so plots don't overlap
    fig.tight_layout()

    # Save the figure as a PNG file
    plt.savefig('inflammation.png')

    # Display the figure
    plt.show()
# Out:
# data/inflammation-01.csv
# data/inflammation-02.csv
# data/inflammation-03.csv

# %% [markdown]
# The plots have some suspicious features not normally found in valid trials:  the maxima plots show unnatural noiseless linear rise and fall; and their minima plots show stepwise features.
#
# The third dataset shows much noisier average and maxima plots that are far less suspicious than the first two datasets, however the minima plot shows that the third dataset minima is consistently zero across every day of the trial.
#
# If we produce a heat map for the third data file we see the following:

# %%
data=np.loadtxt("data/inflammation-03.csv", delimiter=',')
image = plt.imshow(data)
plt.show()

# %% [markdown]
# We can see that there are zero values sporadically distributed across all patients and days of the clinical trial, suggesting that there were potential issues with data collection throughout the trial. In addition, we can see that the last patient in the study didn’t have any inflammation flare-ups at all throughout the trial, suggesting that they may not even suffer from arthritis!

# %% [markdown]
# After spending some time investigating the heat map and statistical plots we gain some insight into the twelve clinical trial datasets.
#
# The datasets appear to fall into two categories:
#
# - ***seemingly “ideal” datasets*** that agree excellently with Dr. Maverick’s claims, but display suspicious maxima and minima (such as inflammation-01.csv and inflammation-02.csv)
# - ***“noisy” datasets*** that somewhat agree with Dr. Maverick’s claims, but show concerning data collection issues such as sporadic missing values and even an unsuitable candidate making it into the clinical trial.
#
# After reviewing these findings, we can conclude that the clinical data has been fabricated by Dr. Maverick based on the identified inconsistencies in the datasets.
#
# Oh well! Lets continue using the data to learn how to program in python!
